# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)
plt.style.use("seaborn-v0_8")
np.random.seed(42)

# %%
import os
import glob
from zipfile import ZipFile

RAW_DATA_DIR = "../Data/Raw_Data"           # ZIP files folder
EXTRACT_DIR = "../Data/Raw_Data/extracted"  # folder to extract CSVs

# Create extraction folder if it doesn't exist
os.makedirs(EXTRACT_DIR, exist_ok=True)

# %%
zip_files = glob.glob(os.path.join(RAW_DATA_DIR, "*.zip"))

for zip_path in zip_files:
    with ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(EXTRACT_DIR)

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\saksh\OneDrive\Documents\GitHub\Aadhar-card-dataAnalysis-UIDAI-Hackathon-project\Notebook

# %%
enrolment_files = glob.glob(os.path.join(EXTRACT_DIR, "api_data_aadhar_enrolment", "*.csv"))

# %%
print(enrolment_files)
# Out:
# ['../Data/Raw_Data/extracted\\api_data_aadhar_enrolment\\api_data_aadhar_enrolment_0_500000.csv', '../Data/Raw_Data/extracted\\api_data_aadhar_enrolment\\api_data_aadhar_enrolment_1000000_1006029.csv', '../Data/Raw_Data/extracted\\api_data_aadhar_enrolment\\api_data_aadhar_enrolment_500000_1000000.csv']

# %%
enrol_df = pd.concat(
    (pd.read_csv(file) for file in enrolment_files),
    ignore_index=True
)
print("Enrolment data shape:", enrol_df.shape)
# Out:
# Enrolment data shape: (1006029, 7)

# %%
demo_files = glob.glob(os.path.join(EXTRACT_DIR, "api_data_aadhar_demographic","*.csv"))
print(demo_files)
# Out:
# ['../Data/Raw_Data/extracted\\api_data_aadhar_demographic\\api_data_aadhar_demographic_0_500000.csv', '../Data/Raw_Data/extracted\\api_data_aadhar_demographic\\api_data_aadhar_demographic_1000000_1500000.csv', '../Data/Raw_Data/extracted\\api_data_aadhar_demographic\\api_data_aadhar_demographic_1500000_2000000.csv', '../Data/Raw_Data/extracted\\api_data_aadhar_demographic\\api_data_aadhar_demographic_2000000_2071700.csv', '../Data/Raw_Data/extracted\\api_data_aadhar_demographic\\api_data_aadhar_demographic_500000_1000000.csv']

# %%
demo_df = pd.concat((pd.read_csv(file) for file in demo_files), ignore_index= True)
print("Demographic updates data shape", demo_df.shape)
# Out:
# Demographic updates data shape (2071700, 6)

# %%
biometric_files = glob.glob(os.path.join(EXTRACT_DIR, "api_data_aadhar_biometric","*.csv"))
print(biometric_files)
# Out:
# ['../Data/Raw_Data/extracted\\api_data_aadhar_biometric\\api_data_aadhar_biometric_0_500000.csv', '../Data/Raw_Data/extracted\\api_data_aadhar_biometric\\api_data_aadhar_biometric_1000000_1500000.csv', '../Data/Raw_Data/extracted\\api_data_aadhar_biometric\\api_data_aadhar_biometric_1500000_1861108.csv', '../Data/Raw_Data/extracted\\api_data_aadhar_biometric\\api_data_aadhar_biometric_500000_1000000.csv']

# %%
biometric_df = pd.concat((pd.read_csv(file) for file in biometric_files), ignore_index= True)
print("Biometric updates data shape", biometric_df.shape)
# Out:
# Biometric updates data shape (1861108, 6)

# %%
enrol_df.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      Meghalaya  East Khasi Hills   793121       11        61
# 1  09-03-2025      Karnataka   Bengaluru Urban   560043       14        33
# 2  09-03-2025  Uttar Pradesh      Kanpur Nagar   208001       29        82
# 3  09-03-2025  Uttar Pradesh           Aligarh   202133       62        29
# 4  09-03-2025      Karnataka   Bengaluru Urban   560016       14        16
#
#    age_18_greater
# 0              37
# 1              39
# 2              12
# 3              15
# 4              21

# %%
demo_df.head()
# Out:
#          date           state    district  pincode  demo_age_5_17  \
# 0  01-03-2025   Uttar Pradesh   Gorakhpur   273213             49
# 1  01-03-2025  Andhra Pradesh    Chittoor   517132             22
# 2  01-03-2025         Gujarat      Rajkot   360006             65
# 3  01-03-2025  Andhra Pradesh  Srikakulam   532484             24
# 4  01-03-2025       Rajasthan     Udaipur   313801             45
#
#    demo_age_17_
# 0           529
# 1           375
# 2           765
# 3           314
# 4           785

# %%
biometric_df.head()
# Out:
#          date              state      district  pincode  bio_age_5_17  \
# 0  01-03-2025            Haryana  Mahendragarh   123029           280
# 1  01-03-2025              Bihar     Madhepura   852121           144
# 2  01-03-2025  Jammu and Kashmir         Punch   185101           643
# 3  01-03-2025              Bihar       Bhojpur   802158           256
# 4  01-03-2025         Tamil Nadu       Madurai   625514           271
#
#    bio_age_17_
# 0          577
# 1          369
# 2         1091
# 3          980
# 4          815

# %%
enrol_df.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'age_0_5', 'age_5_17',
#        'age_18_greater'],
#       dtype='object')

# %%
enrol_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1006029 entries, 0 to 1006028
# Data columns (total 7 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   date            1006029 non-null  object
#  1   state           1006029 non-null  object
#  2   district        1006029 non-null  object
#  3   pincode         1006029 non-null  int64
#  4   age_0_5         1006029 non-null  int64
#  5   age_5_17        1006029 non-null  int64
#  6   age_18_greater  1006029 non-null  int64
# dtypes: int64(4), object(3)
# memory usage: 53.7+ MB

# %%
demo_df.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'demo_age_5_17',
#        'demo_age_17_'],
#       dtype='object')

# %%
demo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2071700 entries, 0 to 2071699
# Data columns (total 6 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   date           object
#  1   state          object
#  2   district       object
#  3   pincode        int64
#  4   demo_age_5_17  int64
#  5   demo_age_17_   int64
# dtypes: int64(3), object(3)
# memory usage: 94.8+ MB

# %%
biometric_df.columns
# Out:
# Index(['date', 'state', 'district', 'pincode', 'bio_age_5_17', 'bio_age_17_'], dtype='object')

# %%
biometric_df.info
# Out:
# <bound method DataFrame.info of                date              state      district  pincode  bio_age_5_17  \
# 0        01-03-2025            Haryana  Mahendragarh   123029           280
# 1        01-03-2025              Bihar     Madhepura   852121           144
# 2        01-03-2025  Jammu and Kashmir         Punch   185101           643
# 3        01-03-2025              Bihar       Bhojpur   802158           256
# 4        01-03-2025         Tamil Nadu       Madurai   625514           271
# ...             ...                ...           ...      ...           ...
# 1861103  07-11-2025             Kerala     Ernakulam   682020             1
# 1861104  07-11-2025             Kerala     Ernakulam   682022             1
# 1861105  07-11-2025             Kerala     Ernakulam   682023             0
# 1861106  07-11-2025             Kerala     Ernakulam   682025             3
# 1861107  07-11-2025             Kerala     Ernakulam   682026             1
#
#          bio_age_17_
# ...

# %%
def clean_columns(df):
    df.columns = (
        df.columns
        .str.strip()
        .str.lower()
        .str.replace(" ", "_")
    )
    return df

# %%
enrol_df = clean_columns(enrol_df)
demo_df  = clean_columns(demo_df)
biometric_df   = clean_columns(biometric_df)

# %%
# Parse dates with explicit format (DD-MM-YYYY)
enrol_df['date'] = pd.to_datetime(enrol_df['date'], format='%d-%m-%Y', errors='coerce')
demo_df['date']  = pd.to_datetime(demo_df['date'], format='%d-%m-%Y', errors='coerce')
biometric_df['date'] = pd.to_datetime(biometric_df['date'], format='%d-%m-%Y', errors='coerce')

# Verify immediately
print("Date parsing verification:")
print(f"Enrol: {enrol_df['date'].notna().sum():,} / {len(enrol_df):,} valid dates ({enrol_df['date'].notna().sum()/len(enrol_df)*100:.1f}%)")
print(f"Demo: {demo_df['date'].notna().sum():,} / {len(demo_df):,} valid dates ({demo_df['date'].notna().sum()/len(demo_df)*100:.1f}%)")
print(f"Bio: {biometric_df['date'].notna().sum():,} / {len(biometric_df):,} valid dates ({biometric_df['date'].notna().sum()/len(biometric_df)*100:.1f}%)")

print("\nSample dates:")
print(enrol_df[['date']].head(10))
# Out:
# Date parsing verification:
# Enrol: 1,006,029 / 1,006,029 valid dates (100.0%)
# Demo: 2,071,700 / 2,071,700 valid dates (100.0%)
# Bio: 1,861,108 / 1,861,108 valid dates (100.0%)
#
# Sample dates:
#         date
# 0 2025-03-02
# 1 2025-03-09
# 2 2025-03-09
# 3 2025-03-09
# 4 2025-03-09
# 5 2025-03-09
# 6 2025-03-09
# 7 2025-03-09
# 8 2025-03-09
# 9 2025-03-09

# %%
def flag_numeric_locations(df):
    df['state_is_numeric'] = df['state'].str.isnumeric()
    df['district_is_numeric'] = df['district'].str.isnumeric()
    return df

# %%
enrol_df = flag_numeric_locations(enrol_df)
demo_df  = flag_numeric_locations(demo_df)
bio_df   = flag_numeric_locations(biometric_df)

# %%
print("Numeric state counts:")
print("Enrolment:", enrol_df['state_is_numeric'].sum())
print("Demographic:", demo_df['state_is_numeric'].sum())
print("Biometric:", bio_df['state_is_numeric'].sum())

print("\nNumeric district counts:")
print("Enrolment:", enrol_df['district_is_numeric'].sum())
print("Demographic:", demo_df['district_is_numeric'].sum())
print("Biometric:", bio_df['district_is_numeric'].sum())
# Out:
# Numeric state counts:
# Enrolment: 22
# Demographic: 2
# Biometric: 0
#
# Numeric district counts:
# Enrolment: 22
# Demographic: 2
# Biometric: 0

# %%
enrol_df.loc[enrol_df['state_is_numeric'], ['state', 'district']].head()
# Out:
#          state district
# 23108   100000   100000
# 46946   100000   100000
# 97816   100000   100000
# 115798  100000   100000
# 153156  100000   100000

# %%
def clean_location_columns(df):
    # State cleaning
    df['state_clean'] = (
        df['state']
        .astype(str)
        .str.strip()
        .str.title()
    )

    # District cleaning
    df['district_clean'] = (
        df['district']
        .astype(str)
        .str.strip()
        .str.title()
    )

    # Mark numeric contamination
    df['state_is_numeric'] = df['state_clean'].str.isnumeric()
    df['district_is_numeric'] = df['district_clean'].str.isnumeric()

    # Replace numeric-only entries with NaN in clean columns
    df.loc[df['state_is_numeric'], 'state_clean'] = pd.NA
    df.loc[df['district_is_numeric'], 'district_clean'] = pd.NA

    return df

# %%
enrol_df = clean_location_columns(enrol_df)
demo_df  = clean_location_columns(demo_df)
bio_df   = clean_location_columns(bio_df)

# %%
def mark_valid_location(df):
    df['valid_location'] = (
        df['state_clean'].notna() &
        df['district_clean'].notna()
    )
    return df

# %%
enrol_df = mark_valid_location(enrol_df)
demo_df  = mark_valid_location(demo_df)
bio_df   = mark_valid_location(bio_df)

# %%
print("Invalid location rows:")
print("Enrolment:", (~enrol_df['valid_location']).sum())
print("Demographic:", (~demo_df['valid_location']).sum())
print("Biometric:", (~bio_df['valid_location']).sum())
# Out:
# Invalid location rows:
# Enrolment: 22
# Demographic: 2
# Biometric: 0

# %%
enrol_df.loc[~enrol_df['valid_location'], ['state', 'district']].head(10)
# Out:
#          state district
# 23108   100000   100000
# 46946   100000   100000
# 97816   100000   100000
# 115798  100000   100000
# 153156  100000   100000
# 160195  100000   100000
# 261778  100000   100000
# 272731  100000   100000
# 470934  100000   100000
# 768773  100000   100000

# %%
import re
def normalize_state_name(state):
    """
    Standardizes Indian state/UT names by:
    - Lowercasing
    - Replacing '&' with 'and'
    - Removing extra spaces
    """
    if pd.isna(state):
        return pd.NA

    state = state.lower().strip()
    state = state.replace("&", "and")
    state = " ".join(state.split())

    return state

# %%
for df in [enrol_df, demo_df, biometric_df]:
    df['state_norm'] = df['state'].apply(normalize_state_name)

# %%
STATE_CANONICAL_MAP = {
    # Andaman & Nicobar
    "andaman and nicobar islands": "Andaman and Nicobar Islands",

    # Dadra & Nagar Haveli / Daman & Diu
    "dadra and nagar haveli": "Dadra and Nagar Haveli and Daman and Diu",
    "daman and diu": "Dadra and Nagar Haveli and Daman and Diu",
    "dadra and nagar haveli and daman and diu": "Dadra and Nagar Haveli and Daman and Diu",

    # Jammu & Kashmir / Ladakh
    "jammu and kashmir": "Jammu and Kashmir",

    # Delhi
    "delhi": "Delhi",

    # Puducherry
    "pondicherry": "Puducherry",

    # Odisha
    "orissa": "Odisha"
}

# %%
def apply_canonical_mapping(state):
    if pd.isna(state):
        return pd.NA
    return STATE_CANONICAL_MAP.get(state, state.title())

# %%
for df in [enrol_df, demo_df, biometric_df]:
    df['state_clean'] = df['state_norm'].apply(apply_canonical_mapping)

# %%
print("Unique states after cleaning:")
print("Enrolment:", enrol_df['state_clean'].nunique())
print("Demographic:", demo_df['state_clean'].nunique())
print("Biometric:", biometric_df['state_clean'].nunique())
# Out:
# Unique states after cleaning:
# Enrolment: 40
# Demographic: 49
# Biometric: 41

# %%
def find_suspicious_states(df, name):
    print(f"\nSuspicious states in {name}:")
    suspicious = (
        df['state_clean']
        .dropna()
        .loc[df['state_clean'].str.contains(r'\d', regex=True)]
        .unique()
    )
    print(suspicious[:20], " ... total:", len(suspicious))


find_suspicious_states(enrol_df, "Enrolment")
find_suspicious_states(demo_df, "Demographic")
find_suspicious_states(biometric_df, "Biometric")
# Out:
# Suspicious states in Enrolment:
# ['100000']  ... total: 1
#
# Suspicious states in Demographic:
# ['100000']  ... total: 1
#
# Suspicious states in Biometric:
# []  ... total: 0

# %%
def is_valid_state_name(state):
    if pd.isna(state):
        return False
    if any(char.isdigit() for char in state):
        return False
    return True

# %%
for df in [enrol_df, demo_df, biometric_df]:
    df['valid_state'] = df['state_clean'].apply(is_valid_state_name)

# %%
def normalize_district_name(district):
    if pd.isna(district):
        return pd.NA
    
    district = district.lower().strip()
    district = district.replace("&", "and")
    district = " ".join(district.split())
    
    return district

for df in [enrol_df, demo_df, biometric_df]:
    df['district_norm'] = df['district'].apply(normalize_district_name)

# %%
def is_valid_district_name(district):
    if pd.isna(district):
        return False
    if any(char.isdigit() for char in district):
        return False
    return True

for df in [enrol_df, demo_df, biometric_df]:
    df['valid_district'] = df['district_norm'].apply(is_valid_district_name)
    df['district_clean'] = df['district_norm'].where(df['valid_district'], pd.NA)

print("Invalid district rows:")
print(f"Enrolment: {(~enrol_df['valid_district']).sum()}")
print(f"Demographic: {(~demo_df['valid_district']).sum()}")
print(f"Biometric: {(~biometric_df['valid_district']).sum()}")
# Out:
# Invalid district rows:
# Enrolment: 11104
# Demographic: 21009
# Biometric: 17207

# %%
# Create analysis_ready flag - ONLY check location validity (NOT dates)
for df in [enrol_df, demo_df, biometric_df]:
    df['analysis_ready'] = (
        df['valid_state'] &
        df['valid_district']
    )

print("Analysis-ready rows (valid state & district):")
print(f"Enrolment: {enrol_df['analysis_ready'].sum():,} / {len(enrol_df):,}")
print(f"Demographic: {demo_df['analysis_ready'].sum():,} / {len(demo_df):,}")
print(f"Biometric: {biometric_df['analysis_ready'].sum():,} / {len(biometric_df):,}")
# Out:
# Analysis-ready rows (valid state & district):
# Enrolment: 994,925 / 1,006,029
# Demographic: 2,050,691 / 2,071,700
# Biometric: 1,843,901 / 1,861,108

# %%
# Create final analysis-ready datasets
final_enrol_df = enrol_df.loc[enrol_df['analysis_ready']].copy()
final_demo_df  = demo_df.loc[demo_df['analysis_ready']].copy()
final_bio_df   = biometric_df.loc[biometric_df['analysis_ready']].copy()

print("Final dataset sizes:")
print(f"Enrolment: {len(final_enrol_df):,} (removed {len(enrol_df) - len(final_enrol_df):,} invalid location rows)")
print(f"Demographic: {len(final_demo_df):,} (removed {len(demo_df) - len(final_demo_df):,} invalid location rows)")
print(f"Biometric: {len(final_bio_df):,} (removed {len(biometric_df) - len(final_bio_df):,} invalid location rows)")

print("\nFinal unique states/districts:")
print(f"Enrolment: {final_enrol_df['state_clean'].nunique()} states, {final_enrol_df['district_clean'].nunique()} districts")
print(f"Demographic: {final_demo_df['state_clean'].nunique()} states, {final_demo_df['district_clean'].nunique()} districts")
print(f"Biometric: {final_bio_df['state_clean'].nunique()} states, {final_bio_df['district_clean'].nunique()} districts")
# Out:
# Final dataset sizes:
# Enrolment: 994,925 (removed 11,104 invalid location rows)
# Demographic: 2,050,691 (removed 21,009 invalid location rows)
# Biometric: 1,843,901 (removed 17,207 invalid location rows)
#
# Final unique states/districts:
# Enrolment: 39 states, 956 districts
# Demographic: 47 states, 953 districts
# Biometric: 41 states, 944 districts

# %%
# Select only the columns needed for analysis
enrolment_final_cols = [
    'date',
    'state_clean',
    'district_clean',
    'pincode',
    'age_0_5',
    'age_5_17',
    'age_18_greater'
]

demographic_final_cols = [
    'date',
    'state_clean',
    'district_clean',
    'pincode',
    'demo_age_5_17',
    'demo_age_17_'
]

biometric_final_cols = [
    'date',
    'state_clean',
    'district_clean',
    'pincode',
    'bio_age_5_17',
    'bio_age_17_'
]

enrolment_final = final_enrol_df[enrolment_final_cols].copy()
demographic_final = final_demo_df[demographic_final_cols].copy()
biometric_final = final_bio_df[biometric_final_cols].copy()

# %%
import os
print("Current working directory:", os.getcwd())
print("\nFiles in current directory:")
for f in os.listdir():
    if f.endswith('.csv'):
        print(f"  {f}")
# Out:
# Current working directory: c:\Users\saksh\OneDrive\Documents\GitHub\Aadhar-card-dataAnalysis-UIDAI-Hackathon-project\Notebook
#
# Files in current directory:

# %%
# Check if our final dataframes exist in memory
print("Checking dataframes in memory:")

try:
    print(f"✓ enrolment_final exists: {len(enrolment_final):,} rows")
except NameError:
    print("✗ enrolment_final NOT FOUND")

try:
    print(f"✓ demographic_final exists: {len(demographic_final):,} rows")
except NameError:
    print("✗ demographic_final NOT FOUND")

try:
    print(f"✓ biometric_final exists: {len(biometric_final):,} rows")
except NameError:
    print("✗ biometric_final NOT FOUND")
# Out:
# Checking dataframes in memory:
# ✓ enrolment_final exists: 994,925 rows
# ✓ demographic_final exists: 2,050,691 rows
# ✓ biometric_final exists: 1,843,901 rows

# %%
# ============================================
# COMPLETE DATA PREPARATION - ALL IN ONE
# ============================================

print("=" * 60)
print("STARTING COMPLETE DATA PREPARATION")
print("=" * 60)

# Step 1: Verify base dataframes exist
print("\n1. Checking base dataframes...")
if 'enrol_df' not in locals() or 'demo_df' not in locals() or 'biometric_df' not in locals():
    print("ERROR: Base dataframes not found! Please run data loading cells first.")
else:
    print(f"✓ enrol_df: {len(enrol_df):,} rows")
    print(f"✓ demo_df: {len(demo_df):,} rows")
    print(f"✓ biometric_df: {len(biometric_df):,} rows")

# Step 2: Ensure state_clean exists
print("\n2. Checking state_clean column...")
if 'state_clean' not in enrol_df.columns:
    print("  Creating state_clean column...")
    for df in [enrol_df, demo_df, biometric_df]:
        df['state_clean'] = df['state'].astype(str).str.strip().str.title()
        df['state_clean'] = df['state_clean'].replace('100000', pd.NA)
print("✓ state_clean ready")

# Step 3: Ensure district_clean exists  
print("\n3. Checking district_clean column...")
if 'district_clean' not in enrol_df.columns:
    print("  Creating district_clean column...")
    for df in [enrol_df, demo_df, biometric_df]:
        df['district_clean'] = df['district'].astype(str).str.strip().str.lower()
        df['district_clean'] = df['district_clean'].str.replace("&", "and")
        df['district_clean'] = df['district_clean'].replace('100000', pd.NA)
print("✓ district_clean ready")

# Step 4: Validate locations
print("\n4. Validating locations...")
def is_valid_name(name):
    if pd.isna(name):
        return False
    if any(char.isdigit() for char in str(name)):
        return False
    return True

for df in [enrol_df, demo_df, biometric_df]:
    df['valid_state'] = df['state_clean'].apply(is_valid_name)
    df['valid_district'] = df['district_clean'].apply(is_valid_name)

print(f"✓ Enrolment valid: {enrol_df['valid_state'].sum():,} states, {enrol_df['valid_district'].sum():,} districts")
print(f"✓ Demographic valid: {demo_df['valid_state'].sum():,} states, {demo_df['valid_district'].sum():,} districts")
print(f"✓ Biometric valid: {biometric_df['valid_state'].sum():,} states, {biometric_df['valid_district'].sum():,} districts")

# Step 5: Create analysis_ready flag
print("\n5. Creating analysis_ready flag...")
for df in [enrol_df, demo_df, biometric_df]:
    df['analysis_ready'] = df['valid_state'] & df['valid_district']

print(f"✓ Enrolment ready: {enrol_df['analysis_ready'].sum():,}")
print(f"✓ Demographic ready: {demo_df['analysis_ready'].sum():,}")
print(f"✓ Biometric ready: {biometric_df['analysis_ready'].sum():,}")

# Step 6: Create final datasets
print("\n6. Creating final datasets...")
final_enrol_df = enrol_df.loc[enrol_df['analysis_ready']].copy()
final_demo_df = demo_df.loc[demo_df['analysis_ready']].copy()
final_bio_df = biometric_df.loc[biometric_df['analysis_ready']].copy()

print(f"✓ final_enrol_df: {len(final_enrol_df):,} rows")
print(f"✓ final_demo_df: {len(final_demo_df):,} rows")
print(f"✓ final_bio_df: {len(final_bio_df):,} rows")

# Step 7: Select columns for export
print("\n7. Selecting final columns...")
enrolment_final = final_enrol_df[[
    'date', 'state_clean', 'district_clean', 'pincode',
    'age_0_5', 'age_5_17', 'age_18_greater'
]].copy()

demographic_final = final_demo_df[[
    'date', 'state_clean', 'district_clean', 'pincode',
    'demo_age_5_17', 'demo_age_17_'
]].copy()

biometric_final = final_bio_df[[
    'date', 'state_clean', 'district_clean', 'pincode',
    'bio_age_5_17', 'bio_age_17_'
]].copy()

print(f"✓ enrolment_final: {len(enrolment_final):,} rows, {enrolment_final.columns.tolist()}")
print(f"✓ demographic_final: {len(demographic_final):,} rows, {demographic_final.columns.tolist()}")
print(f"✓ biometric_final: {len(biometric_final):,} rows, {biometric_final.columns.tolist()}")

print("\n" + "=" * 60)
print("DATA PREPARATION COMPLETE!")
print("=" * 60)
# Out:
# ...
# STARTING COMPLETE DATA PREPARATION
# ...
#
# 1. Checking base dataframes...
# ✓ enrol_df: 1,006,029 rows
# ✓ demo_df: 2,071,700 rows
# ✓ biometric_df: 1,861,108 rows
#
# 2. Checking state_clean column...
# ✓ state_clean ready
#
# 3. Checking district_clean column...
# ✓ district_clean ready
#
# 4. Validating locations...
# ✓ Enrolment valid: 1,006,007 states, 994,925 districts
# ✓ Demographic valid: 2,071,698 states, 2,050,691 districts
# ✓ Biometric valid: 1,861,108 states, 1,843,901 districts
#
# 5. Creating analysis_ready flag...
# ✓ Enrolment ready: 994,925
# ✓ Demographic ready: 2,050,691
# ✓ Biometric ready: 1,843,901
#
# 6. Creating final datasets...
# ✓ final_enrol_df: 994,925 rows
# ✓ final_demo_df: 2,050,691 rows
# ✓ final_bio_df: 1,843,901 rows
#
# 7. Selecting final columns...
# ✓ enrolment_final: 994,925 rows, ['date', 'state_clean', 'district_clean', 'pincode', 'age_0_5', 'age_5_17', 'age_18_greater']
# ...

# %%
# Export the final datasets
print("Exporting to CSV...")

try:
    enrolment_final.to_csv("clean_enrolment_base.csv", index=False)
    print("✓ clean_enrolment_base.csv created")
except Exception as e:
    print(f"✗ Error creating enrolment CSV: {e}")

try:
    demographic_final.to_csv("clean_demographic_base.csv", index=False)
    print("✓ clean_demographic_base.csv created")
except Exception as e:
    print(f"✗ Error creating demographic CSV: {e}")

try:
    biometric_final.to_csv("clean_biometric_base.csv", index=False)
    print("✓ clean_biometric_base.csv created")
except Exception as e:
    print(f"✗ Error creating biometric CSV: {e}")

print("\nVerifying files...")
import os
for filename in ["clean_enrolment_base.csv", "clean_demographic_base.csv", "clean_biometric_base.csv"]:
    if os.path.exists(filename):
        size_mb = os.path.getsize(filename) / (1024*1024)
        print(f"✓ {filename}: {size_mb:.2f} MB")
    else:
        print(f"✗ {filename}: NOT FOUND!")
# Out:
# Exporting to CSV...
# ✓ clean_enrolment_base.csv created
# ✓ clean_demographic_base.csv created
# ✓ clean_biometric_base.csv created
#
# Verifying files...
# ✓ clean_enrolment_base.csv: 43.18 MB
# ✓ clean_demographic_base.csv: 86.32 MB
# ✓ clean_biometric_base.csv: 77.77 MB

# %%
# Verify exported files
import os

files = ["clean_enrolment_base.csv", "clean_demographic_base.csv", "clean_biometric_base.csv"]

for f in files:
    if os.path.exists(f):
        size_mb = os.path.getsize(f) / (1024*1024)
        print(f"{f} exists, size: {size_mb:.2f} MB")
    else:print(f"{f} NOT FOUND!")

# Load and verify
enrol_check = pd.read_csv("clean_enrolment_base.csv")
demo_check = pd.read_csv("clean_demographic_base.csv")
bio_check = pd.read_csv("clean_biometric_base.csv")

print("\nRow counts verification:")
print(f"Enrolment: {len(enrol_check):,}")
print(f"Demographic: {len(demo_check):,}")
print(f"Biometric: {len(bio_check):,}")

print("\nColumn names:")
print(f"Enrolment: {enrol_check.columns.tolist()}")
print(f"Demographic: {demo_check.columns.tolist()}")
print(f"Biometric: {bio_check.columns.tolist()}")
# Out:
# clean_enrolment_base.csv exists, size: 43.18 MB
# clean_demographic_base.csv exists, size: 86.32 MB
# clean_biometric_base.csv exists, size: 77.77 MB
#
# Row counts verification:
# Enrolment: 994,925
# Demographic: 2,050,691
# Biometric: 1,843,901
#
# Column names:
# Enrolment: ['date', 'state_clean', 'district_clean', 'pincode', 'age_0_5', 'age_5_17', 'age_18_greater']
# Demographic: ['date', 'state_clean', 'district_clean', 'pincode', 'demo_age_5_17', 'demo_age_17_']
# Biometric: ['date', 'state_clean', 'district_clean', 'pincode', 'bio_age_5_17', 'bio_age_17_']

# %%
# Verify exported files
import os

files = ["clean_enrolment_base.csv", "clean_demographic_base.csv", "clean_biometric_base.csv"]

for f in files:
    if os.path.exists(f):
        size_mb = os.path.getsize(f) / (1024*1024)
        print(f"{f} exists, size: {size_mb:.2f} MB")
    else:
        print(f"{f} NOT FOUND!")

# Load and verify
enrol_check = pd.read_csv("clean_enrolment_base.csv")
demo_check = pd.read_csv("clean_demographic_base.csv")
bio_check = pd.read_csv("clean_biometric_base.csv")

print("\nRow counts verification:")
print(f"Enrolment: {len(enrol_check):,}")
print(f"Demographic: {len(demo_check):,}")
print(f"Biometric: {len(bio_check):,}")

print("\nColumn names:")
print(f"Enrolment: {enrol_check.columns.tolist()}")
print(f"Demographic: {demo_check.columns.tolist()}")
print(f"Biometric: {bio_check.columns.tolist()}")
# Out:
# clean_enrolment_base.csv exists, size: 43.18 MB
# clean_demographic_base.csv exists, size: 86.32 MB
# clean_biometric_base.csv exists, size: 77.77 MB
#
# Row counts verification:
# Enrolment: 994,925
# Demographic: 2,050,691
# Biometric: 1,843,901
#
# Column names:
# Enrolment: ['date', 'state_clean', 'district_clean', 'pincode', 'age_0_5', 'age_5_17', 'age_18_greater']
# Demographic: ['date', 'state_clean', 'district_clean', 'pincode', 'demo_age_5_17', 'demo_age_17_']
# Biometric: ['date', 'state_clean', 'district_clean', 'pincode', 'bio_age_5_17', 'bio_age_17_']

# %%
print("=== FINAL SUMMARY STATISTICS ===\n")

print("Enrolment Dataset:")
print(enrolment_final.describe())
print(f"\nTotal enrolments by age group:")
print(enrolment_final[['age_0_5','age_5_17','age_18_greater']].sum())

print("\n" + "="*50 + "\n")

print("Demographic Dataset:")
print(demographic_final.describe())

print("\n" + "="*50 + "\n")

print("Biometric Dataset:")
print(biometric_final.describe())
# Out:
# === FINAL SUMMARY STATISTICS ===
#
# Enrolment Dataset:
#                                 date        pincode        age_0_5  \
# count                         994925  994925.000000  994925.000000
# mean   2025-10-23 18:43:59.111088384  516327.986734       3.514702
# min              2025-03-02 00:00:00  110001.000000       0.000000
# 25%              2025-09-19 00:00:00  362275.000000       1.000000
# 50%              2025-10-27 00:00:00  516107.000000       2.000000
# 75%              2025-11-15 00:00:00  695009.000000       3.000000
# max              2025-12-31 00:00:00  855456.000000    2688.000000
# std                              NaN  205571.461874      17.592445
#
#             age_5_17  age_18_greater
# count  994925.000000   994925.000000
# mean        1.712573        0.166796
# min         0.000000        0.000000
# 25%         0.000000        0.000000
# 50%         0.000000        0.000000
# 75%         1.000000        0.000000
# max      1812.000000      855.000000
# ...
